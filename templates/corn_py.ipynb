# %% [markdown]
# <a href="https://colab.research.google.com/github/Cut-c/fraud_detection/blob/main/templates/corn_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
